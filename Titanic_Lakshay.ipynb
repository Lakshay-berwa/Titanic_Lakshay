# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
titanic.isnull().sum()
titanic.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
titanic.dropna(inplace=True)
titanic.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 14)

# %%
sns.countplot(x='survived', data=titanic)
plt.title('Survived count (0 = Died , 1 = survived)')
plt.show()

# %%
sns.countplot(x ="sex", hue ="survived",data = titanic)
plt.title("Survived by Gender")
plt.show()

# %%
sns.countplot(x ="class", hue ="survived",data = titanic)
plt.title("Survived By Passenger Class ")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='age_group', y='Count', hue= 'Survival Status', data=age_survived_melted, palette=['skyblue','lightcoral'])
plt.title('Survived By Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Passengers')
plt.xticks(rotation=45)
plt.legend(title='Survival')
plt.tight_layout()
plt.show()

# %%
survival_counts = titanic['survived'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(survival_counts, labels=['Died', 'Survived'], autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen'])
plt.title('Proportion of Survivors vs. Non-Survivors')
plt.show()

# %% [markdown]
# Full Analysis Short Conclusion:
#
# We loaded and cleaned the Titanic dataset, handling missing values.
# Our visualizations (count plots, bar charts, pie charts) consistently showed that gender (females had higher survival rates) and passenger class (first-class passengers had higher survival rates) were the most significant factors determining survival.
# The overall survival rate was approximately 40.45%.
#
# Data Loading :-This part explains that was began by loading the dataset and then used commends like head(),info(),isnull(),sum() to a first look at the data
#
# Data cleaning :- we then discussed how we cleaned the data . A key step mentioned was deoppind the 'cloumn' because it had too many missing values
